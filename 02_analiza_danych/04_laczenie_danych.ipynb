# %% [markdown]
# <a href="https://colab.research.google.com/github/kondimidi/data-science-boot/blob/main/02_analiza_danych/04_laczenie_danych.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Pandas
# Strona biblioteki: [https://pandas.pydata.org/](https://pandas.pydata.org/)
# Dokumentacja: [https://pandas.pydata.org/pandas-docs/stable/](https://pandas.pydata.org/pandas-docs/stable/)
#
# Podstawowa biblioteka do analizy danych w języku Python.
#
# Aby zainstalować bibliotekę Pandas użyj polecenia poniżej:
# ```
# pip install pandas
# ```
# ### Spis treści:
# 1. [Import bibliotek](#a1)
# 2. [Wczytanie danych](#a2)
# 3. [Preprocessing](#a3)
# 4. [Konkatenacja danych](#a4)
# 5. [Metoda append()](#a5)

# %% [markdown]
# ### <a name='a1'></a> Import bibliotek

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.2'

# %% [markdown]
# ### <a name='a2'></a> Wczytanie danych

# %%
def fetch_financial_data(company='AMZN'):
    """
    This function fetch stock market quotations.
    """
    import pandas_datareader.data as web
    return web.DataReader(name=company, data_source='stooq')

apple = fetch_financial_data('AAPL')
amazon = fetch_financial_data('AMZN')
google = fetch_financial_data('GOOGL')
uber = fetch_financial_data('UBER')

# %%
uber.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1256 entries, 2025-03-13 to 2020-03-16
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1256 non-null   float64
#  1   High    1256 non-null   float64
#  2   Low     1256 non-null   float64
#  3   Close   1256 non-null   float64
#  4   Volume  1256 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 58.9 KB

# %%
apple.head()
# Out:
#                Open      High     Low   Close    Volume
# Date
# 2025-03-13  215.950  216.8394  208.42  209.68  61368330
# 2025-03-12  220.140  221.7500  214.91  216.98  62547467
# 2025-03-11  223.805  225.8399  217.45  220.84  76137410
# 2025-03-10  235.540  236.1600  224.22  227.48  72071197
# 2025-03-07  235.105  241.3700  234.76  239.07  46273565

# %% [markdown]
# ### <a name='a3'></a> Preprocessing

# %%
apple.columns = ['apple_' + col.lower() for col in apple.columns]
amazon.columns = ['amazon_' + col.lower() for col in amazon.columns]
google.columns = ['google_' + col.lower() for col in google.columns]
uber.columns = ['uber_' + col.lower() for col in uber.columns]

# %%
apple.head()
# Out:
#             apple_open  apple_high  apple_low  apple_close  apple_volume
# Date
# 2025-03-13     215.950    216.8394     208.42       209.68      61368330
# 2025-03-12     220.140    221.7500     214.91       216.98      62547467
# 2025-03-11     223.805    225.8399     217.45       220.84      76137410
# 2025-03-10     235.540    236.1600     224.22       227.48      72071197
# 2025-03-07     235.105    241.3700     234.76       239.07      46273565

# %% [markdown]
# ### <a name='a4'></a> Konkatenacja danych

# %%
df = pd.concat(objs=[apple, amazon, google, uber], axis=1)
df.head(3)
# Out:
#             apple_open  apple_high  apple_low  apple_close  apple_volume  \
# Date
# 2025-03-13     215.950    216.8394     208.42       209.68      61368330
# 2025-03-12     220.140    221.7500     214.91       216.98      62547467
# 2025-03-11     223.805    225.8399     217.45       220.84      76137410
#
#             amazon_open  amazon_high  amazon_low  amazon_close  amazon_volume  \
# Date
# 2025-03-13      198.165     198.8799      191.82        193.89       41270761
# 2025-03-12      200.720     201.5200      195.29        198.89       43679284
# 2025-03-11      193.900     200.1800      193.40        196.59       54002880
#
#             google_open  google_high  google_low  google_close  google_volume  \
# Date
# 2025-03-13      166.035     166.1300      162.11        162.76       31756214
# 2025-03-12      166.580     167.6399      163.53        167.11       28372396
# 2025-03-11      164.910     166.7500      161.37        164.04       39587414
#
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2025-03-13     71.725      72.00     69.36       69.51     15272232
# 2025-03-12     72.310      72.42     69.55       71.20     17315032
# 2025-03-11     71.440      74.25     69.57       70.65     26668190

# %%
pd.set_option('display.float_format', lambda x: f'{x:.2f}')
df.describe().T
# Out:
#                 count        mean         std         min         25%  \
# apple_open    1256.00      158.31       41.84       55.35      131.05
# apple_high    1256.00      160.05       42.08       55.45      132.22
# apple_low     1256.00      156.67       41.62       51.60      129.75
# apple_close   1256.00      158.45       41.89       54.45      130.83
# apple_volume  1256.00 87165910.41 49219862.79 23260251.00 54320674.25
# amazon_open   1256.00      151.59       33.66       82.08      126.03
# amazon_high   1256.00      153.43       33.71       83.48      127.83
# amazon_low    1256.00      149.60       33.45       81.30      124.30
# amazon_close  1256.00      151.55       33.58       81.82      126.08
# amazon_volume 1256.00 66182287.97 32476556.34 15007497.00 44408526.00
# google_open   1256.00      123.12       33.44       52.63       97.75
# google_high   1256.00      124.53       33.67       53.15       99.49
# google_low    1256.00      121.78       33.18       50.26       96.63
# google_close  1256.00      123.18       33.41       52.52       98.24
# google_volume 1256.00 32702583.95 14204309.51  9346519.00 23439982.00
# uber_open     1256.00       46.63       16.65       15.96       32.37
# uber_high     1256.00       47.48       16.76       17.80       33.02
# uber_low      1256.00       45.76       16.47       13.71       31.58
# uber_close    1256.00       46.62       16.60       14.82       32.46
# uber_volume   1256.00 24594315.52 16899095.56  5200356.00 15776639.75
#
#                       50%          75%          max
# apple_open         156.17       182.21       257.91
# apple_high         158.20       183.99       259.81
# apple_low          153.12       180.52       257.35
# apple_close        155.64       182.39       258.74
# apple_volume  74550567.50 103022011.50 413811381.00
# amazon_open        156.79       173.12       239.01
# amazon_high        158.72       174.63       242.52
# amazon_low         154.53       171.31       238.03
# amazon_close       156.44       172.87       242.06
# amazon_volume 58803201.00  78628092.00 272661720.00
# google_open        122.70       143.35       203.39
# google_high        124.30       144.17       207.05
# google_low         121.69       141.62       202.81
# google_close       122.87       143.04       206.38
# google_volume 29213636.50  37461791.25 123645829.00
# uber_open           44.09        60.09        85.64
# uber_high           44.88        61.01        87.00
# uber_low            43.39        59.21        84.18
# uber_close          44.11        60.30        86.34
# uber_volume   20625637.00  28205929.25 364261230.00

# %%
df.corr()
# Out:
#                apple_open  apple_high  apple_low  apple_close  apple_volume  \
# apple_open           1.00        1.00       1.00         1.00         -0.62
# apple_high           1.00        1.00       1.00         1.00         -0.62
# apple_low            1.00        1.00       1.00         1.00         -0.63
# apple_close          1.00        1.00       1.00         1.00         -0.63
# apple_volume        -0.62       -0.62      -0.63        -0.63          1.00
# amazon_open          0.54        0.54       0.54         0.54         -0.19
# amazon_high          0.54        0.54       0.54         0.54         -0.18
# amazon_low           0.54        0.54       0.54         0.54         -0.20
# amazon_close         0.54        0.54       0.54         0.54         -0.19
# amazon_volume       -0.57       -0.56      -0.57        -0.57          0.65
# google_open          0.90        0.90       0.90         0.90         -0.57
# google_high          0.90        0.90       0.90         0.90         -0.57
# google_low           0.90        0.90       0.90         0.90         -0.58
# google_close         0.90        0.90       0.90         0.90         -0.57
# google_volume       -0.29       -0.29      -0.30        -0.29          0.46
# uber_open            0.65        0.65       0.66         0.65         -0.40
# uber_high            0.65        0.65       0.66         0.65         -0.40
# uber_low             0.66        0.65       0.66         0.66         -0.41
# uber_close           0.65        0.65       0.66         0.65         -0.40
# uber_volume         -0.09       -0.09      -0.09        -0.09          0.20
#
#                amazon_open  amazon_high  amazon_low  amazon_close  \
# apple_open            0.54         0.54        0.54          0.54
# apple_high            0.54         0.54        0.54          0.54
# apple_low             0.54         0.54        0.54          0.54
# apple_close           0.54         0.54        0.54          0.54
# apple_volume         -0.19        -0.18       -0.20         -0.19
# amazon_open           1.00         1.00        1.00          1.00
# amazon_high           1.00         1.00        1.00          1.00
# amazon_low            1.00         1.00        1.00          1.00
# amazon_close          1.00         1.00        1.00          1.00
# amazon_volume        -0.35        -0.34       -0.36         -0.35
# google_open           0.71         0.71        0.71          0.71
# google_high           0.71         0.71        0.71          0.71
# google_low            0.71         0.71        0.72          0.71
# google_close          0.71         0.71        0.71          0.71
# google_volume        -0.25        -0.24       -0.26         -0.25
# uber_open             0.77         0.77        0.77          0.77
# uber_high             0.77         0.77        0.78          0.77
# uber_low              0.77         0.76        0.77          0.77
# uber_close            0.77         0.76        0.77          0.77
# uber_volume          -0.12        -0.12       -0.13         -0.12
#
#                amazon_volume  google_open  google_high  google_low  \
# apple_open             -0.57         0.90         0.90        0.90
# apple_high             -0.56         0.90         0.90        0.90
# apple_low              -0.57         0.90         0.90        0.90
# apple_close            -0.57         0.90         0.90        0.90
# apple_volume            0.65        -0.57        -0.57       -0.58
# amazon_open            -0.35         0.71         0.71        0.71
# amazon_high            -0.34         0.71         0.71        0.71
# amazon_low             -0.36         0.71         0.71        0.72
# amazon_close           -0.35         0.71         0.71        0.71
# amazon_volume           1.00        -0.55        -0.55       -0.56
# google_open            -0.55         1.00         1.00        1.00
# google_high            -0.55         1.00         1.00        1.00
# google_low             -0.56         1.00         1.00        1.00
# google_close           -0.56         1.00         1.00        1.00
# google_volume           0.55        -0.31        -0.30       -0.32
# uber_open              -0.50         0.72         0.71        0.72
# uber_high              -0.49         0.72         0.71        0.72
# uber_low               -0.51         0.72         0.72        0.72
# uber_close             -0.50         0.72         0.71        0.72
# uber_volume             0.25        -0.09        -0.08       -0.09
#
#                google_close  google_volume  uber_open  uber_high  uber_low  \
# apple_open             0.90          -0.29       0.65       0.65      0.66
# apple_high             0.90          -0.29       0.65       0.65      0.65
# apple_low              0.90          -0.30       0.66       0.66      0.66
# apple_close            0.90          -0.29       0.65       0.65      0.66
# apple_volume          -0.57           0.46      -0.40      -0.40     -0.41
# amazon_open            0.71          -0.25       0.77       0.77      0.77
# amazon_high            0.71          -0.24       0.77       0.77      0.76
# amazon_low             0.71          -0.26       0.77       0.78      0.77
# amazon_close           0.71          -0.25       0.77       0.77      0.77
# amazon_volume         -0.56           0.55      -0.50      -0.49     -0.51
# google_open            1.00          -0.31       0.72       0.72      0.72
# google_high            1.00          -0.30       0.71       0.71      0.72
# google_low             1.00          -0.32       0.72       0.72      0.72
# google_close           1.00          -0.31       0.72       0.72      0.72
# google_volume         -0.31           1.00      -0.27      -0.26     -0.27
# uber_open              0.72          -0.27       1.00       1.00      1.00
# uber_high              0.72          -0.26       1.00       1.00      1.00
# uber_low               0.72          -0.27       1.00       1.00      1.00
# uber_close             0.72          -0.27       1.00       1.00      1.00
# uber_volume           -0.09           0.26      -0.19      -0.18     -0.20
#
#                uber_close  uber_volume
# apple_open           0.65        -0.09
# apple_high           0.65        -0.09
# apple_low            0.66        -0.09
# apple_close          0.65        -0.09
# apple_volume        -0.40         0.20
# amazon_open          0.77        -0.12
# amazon_high          0.76        -0.12
# amazon_low           0.77        -0.13
# amazon_close         0.77        -0.12
# amazon_volume       -0.50         0.25
# google_open          0.72        -0.09
# google_high          0.71        -0.08
# google_low           0.72        -0.09
# google_close         0.72        -0.09
# google_volume       -0.27         0.26
# uber_open            1.00        -0.19
# uber_high            1.00        -0.18
# uber_low             1.00        -0.20
# uber_close           1.00        -0.19
# uber_volume         -0.19         1.00

# %%
df.columns
# Out:
# Index(['apple_open', 'apple_high', 'apple_low', 'apple_close', 'apple_volume',
#        'amazon_open', 'amazon_high', 'amazon_low', 'amazon_close',
#        'amazon_volume', 'google_open', 'google_high', 'google_low',
#        'google_close', 'google_volume', 'uber_open', 'uber_high', 'uber_low',
#        'uber_close', 'uber_volume'],
#       dtype='object')

# %%
closes = [col for col in df.columns if col.endswith('close')]
closes
# Out:
# ['apple_close', 'amazon_close', 'google_close', 'uber_close']

# %%
df[closes].corr()
# Out:
#               apple_close  amazon_close  google_close  uber_close
# apple_close          1.00          0.54          0.90        0.65
# amazon_close         0.54          1.00          0.71        0.77
# google_close         0.90          0.71          1.00        0.72
# uber_close           0.65          0.77          0.72        1.00

# %%
closes = [col for col in df.columns if col.endswith('close') or col.endswith('volume')]
closes
# Out:
# ['apple_close',
#  'apple_volume',
#  'amazon_close',
#  'amazon_volume',
#  'google_close',
#  'google_volume',
#  'uber_close',
#  'uber_volume']

# %%
df[closes].corr()
# Out:
#                apple_close  apple_volume  amazon_close  amazon_volume  \
# apple_close           1.00         -0.63          0.54          -0.57
# apple_volume         -0.63          1.00         -0.19           0.65
# amazon_close          0.54         -0.19          1.00          -0.35
# amazon_volume        -0.57          0.65         -0.35           1.00
# google_close          0.90         -0.57          0.71          -0.56
# google_volume        -0.29          0.46         -0.25           0.55
# uber_close            0.65         -0.40          0.77          -0.50
# uber_volume          -0.09          0.20         -0.12           0.25
#
#                google_close  google_volume  uber_close  uber_volume
# apple_close            0.90          -0.29        0.65        -0.09
# apple_volume          -0.57           0.46       -0.40         0.20
# amazon_close           0.71          -0.25        0.77        -0.12
# amazon_volume         -0.56           0.55       -0.50         0.25
# google_close           1.00          -0.31        0.72        -0.09
# google_volume         -0.31           1.00       -0.27         0.26
# uber_close             0.72          -0.27        1.00        -0.19
# uber_volume           -0.09           0.26       -0.19         1.00

# %% [markdown]
# ### <a name='a5'></a> Metoda append()

# %%
uber.head(3)
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2025-03-13      71.72      72.00     69.36       69.51     15272232
# 2025-03-12      72.31      72.42     69.55       71.20     17315032
# 2025-03-11      71.44      74.25     69.57       70.65     26668190

# %%
uber_6 = uber[uber.index.month == 6]
uber_6
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2024-06-28      70.81      73.26     70.77       72.68     21375880
# 2024-06-27      70.98      71.32     70.07       70.34      9650481
# 2024-06-26      70.94      71.60     70.55       70.85     10232568
# 2024-06-25      71.86      72.94     70.22       71.38     18911562
# 2024-06-24      69.83      71.23     69.75       70.54     12479277
# ...               ...        ...       ...         ...          ...
# 2020-06-05      37.53      38.78     36.92       37.21     30393429
# 2020-06-04      36.42      37.30     36.28       36.43     17423577
# 2020-06-03      36.20      37.37     36.14       36.75     23051776
# 2020-06-02      36.16      36.42     35.26       35.81     19328415
# 2020-06-01      35.64      36.39     35.16       35.82     21893806
#
# [105 rows x 5 columns]

# %%
uber_7 = uber[uber.index.month == 7]
uber_7
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2024-07-31      63.88      65.18     63.66       64.47     18209679
# 2024-07-30      64.15      64.77     62.61       63.09     16506187
# 2024-07-29      64.83      65.26     63.72       63.76     16906996
# 2024-07-26      66.10      66.26     64.18       64.40     17379446
# 2024-07-25      66.00      69.37     64.40       65.74     22596919
# ...               ...        ...       ...         ...          ...
# 2020-07-08      33.21      33.97     32.68       33.93     24602369
# 2020-07-07      32.46      33.56     32.39       32.82     34874658
# 2020-07-06      33.10      33.20     31.76       32.52     42392222
# 2020-07-02      31.02      31.57     30.51       30.68     14981137
# 2020-07-01      30.96      31.27     30.16       30.43     13611544
#
# [105 rows x 5 columns]

# %%
uber_6_7 = pd.concat([uber_6, uber_7])
uber_6_7
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2024-06-28      70.81      73.26     70.77       72.68     21375880
# 2024-06-27      70.98      71.32     70.07       70.34      9650481
# 2024-06-26      70.94      71.60     70.55       70.85     10232568
# 2024-06-25      71.86      72.94     70.22       71.38     18911562
# 2024-06-24      69.83      71.23     69.75       70.54     12479277
# ...               ...        ...       ...         ...          ...
# 2020-07-08      33.21      33.97     32.68       33.93     24602369
# 2020-07-07      32.46      33.56     32.39       32.82     34874658
# 2020-07-06      33.10      33.20     31.76       32.52     42392222
# 2020-07-02      31.02      31.57     30.51       30.68     14981137
# 2020-07-01      30.96      31.27     30.16       30.43     13611544
#
# [210 rows x 5 columns]
